# %%
from bs4 import BeautifulSoup as bs

# %%
#loop
#run the below part for lineaer plot by time
l_total=[]
l_deaths=[]
l_recovered=[]
ct=0

# %%
import requests 
URL = "https://www.worldometers.info/coronavirus"
r = requests.get(URL)

# %%
soup = bs(r.content, 'html5lib') 
main = soup.findAll('div', attrs = {'class':'maincounter-number'}) 
total=main[0].text.strip().replace(',',"")
death=main[1].text.strip().replace(',',"")
recovered=main[2].text.strip().replace(',',"")
t=int(total)
d=int(death)
r=int(recovered)
l_total.append(t)
l_deaths.append(d)
l_recovered.append(r)

# %%
import matplotlib.pyplot as plt

labels = ['Remaining Cases', 'Deaths', 'Recovered']
sizes = [t-d-r,d,r]
explode = (0, 0.1, 0)  
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')
plt.tight_layout()
plt.show()
